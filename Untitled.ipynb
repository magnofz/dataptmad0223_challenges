# %%
import pandas as pd

# %%
gta = pd.read_csv('./data/gta_data_batch_1.csv')
gta.loc[gta['features'].isnull(), ['title', 'features']]
# null_displ = df2.loc[df2['displ'].isnull(), ['year', 'make', 'model', 'trany', 'drive','fuelType','cylinders', 'displ']]
# Out:
#                             title features
# 12   GTA 5: Benefactor Dubsta 6x6      NaN
# 15        GTA 5: Pfister Comet SR      NaN
# 20  GTA 5: Grotti Cheetah Classic      NaN
# 43         GTA 5: Bravado Gresley      NaN
# 56            GTA 5: Dinka Thrust      NaN
# 62   GTA 5: Dundreary Landstalker      NaN

# %%
gta.head()
# Out:
#    Unnamed: 0                         title vehicle_class manufacturer  \
# 0           0               GTA 5:  Volatol        Planes          NaN
# 1           1                 GTA 5: Sadler       Utility        Vapid
# 2           2  GTA 5: Benefactor Terrorbyte    Commercial   Benefactor
# 3           3           GTA 5: Mammoth Dodo        Planes      Mammoth
# 4           4            GTA 5: Fathom FQ 2          SUVs       Fathom
#
#                                             features             acquisition  \
# 0  Armored Vehicle, Bombs Mod, Bulletproof - Rear...  Warstock Cache & Carry
# 1  Has Variants, Snow Vehicle - North Yankton, To...   Can be stolen / found
# 2  Armored Vehicle, Bulletproof - Front, Bulletpr...  Warstock Cache & Carry
# 3  Armored Vehicle, Bulletproof - Rear, Float on ...           Elitás Travel
# 4                                      Mystery Prize   Can be stolen / found
#
#         price            storage_location              delivery_method  \
# 0  $3,724,000  Hangar (Personal Aircraft)  Interaction Menu - Aircraft
# 1     $35,000   Garage (Personal Vehicle)                     Mechanic
# 2  $1,375,000         Nightclub Warehouse  Interaction Menu - Services
# 3    $500,000             Pegasus Vehicle            Pegasus Concierge
# 4     $50,000   Garage (Personal Vehicle)                     Mechanic
#
#               modifications  ... weapon2_resistance weapon3_resistance  \
# 0  Hangar Aircraft Workshop  ...                  1                  2
# 1        Los Santos Customs  ...                  1                  2
# 2          Point of Storage  ...                 34                 81
# 3            Paint Job Only  ...                  1                  2
# 4        Los Santos Customs  ...                  1                  2
#
#   weapon4_resistance weapon5_resistance         speed         acceleration  \
# 0                  1                  1  Speed\n76.07  Acceleration\n28.58
# 1                  1                  1  Speed\n69.75  Acceleration\n50.00
# 2                 17                  8  Speed\n64.39  Acceleration\n40.00
# 3                  1                  1  Speed\n76.07  Acceleration\n25.00
# 4                  1                  1  Speed\n72.43  Acceleration\n45.00
#
#           braking         handling         overall  \
# 0  Braking\n32.50   Handling\n1.01  Overall\n34.54
# 1  Braking\n20.00  Handling\n62.12  Overall\n50.47
# 2   Braking\n8.33  Handling\n59.09  Overall\n42.95
# 3  Braking\n18.99  Handling\n25.95  Overall\n36.50
# 4   Braking\n8.33  Handling\n60.61  Overall\n46.59
#
#                                          vehicle_url
# 0  https://www.gtabase.com//grand-theft-auto-v/ve...
# 1  https://www.gtabase.com//grand-theft-auto-v/ve...
# 2  https://www.gtabase.com//grand-theft-auto-v/ve...
# 3  https://www.gtabase.com//grand-theft-auto-v/ve...
# 4  https://www.gtabase.com//grand-theft-auto-v/ve...
#
# [5 rows x 35 columns]
